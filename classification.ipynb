# %% [markdown]
# ## Test
#
# From GPT

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# données d'entraînement
texts = [
    "contrat d'assurance habitation",
    "déclaration de sinistre",
    "prime d'assurance annuelle",
    "assurance voiture obligatoire",
    
    "recette de gâteau",
    "match de football",
    "programme informatique",
    "voyage en avion"
]

labels = [
    1,1,1,1,   # assurance
    0,0,0,0    # pas assurance
]

# transformation du texte
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# modèle
model = LogisticRegression()
model.fit(X, labels)

# test 1
phrase = ["je dois déclarer un sinistre"]
X_test = vectorizer.transform(phrase)

prediction = model.predict(X_test)

print("Assurance ?" , prediction[0], prediction)

# test 2
phrase = ["contrat"]
X_test = vectorizer.transform(phrase)

prediction = model.predict(X_test)

print("Assurance ?" , prediction[0])
# Out:
# Assurance ? 1 [1]
# Assurance ? 1
