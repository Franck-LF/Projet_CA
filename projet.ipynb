# %% [markdown]
# # <center>Text Classification

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Downloading Data

# %% [markdown]
# **Toulouse pulic library loans dataset**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("grimespoint/toulouse-public-library-mdiathque-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 712k/712k [00:00<00:00, 1.59MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Utilisateur\.cache\kagglehub\datasets\grimespoint\toulouse-public-library-mdiathque-dataset\versions\2

# %% [markdown]
# ## Reading Data

# %%
df = pd.read_csv("CSV/toulouse_public_library_loans.csv", sep=";")
df
# Out:
#          year  nb_loans                           title  \
# 0      2023.0       207              Top Gun : Maverick
# 1      2023.0       193    Trois mille ans à t'attendre
# 2      2023.0       152          Compétition officielle
# 3      2023.0       151                  Licorice pizza
# 4      2023.0       144                     Le discours
# ...       ...       ...                             ...
# 21441  2023.0        19                 The Kick inside
# 21442  2023.0        19  Sometimes I might be introvert
# 21443  2023.0        17               Metronomy forever
# 21444  2023.0        16                           S&M 2
# 21445  2023.0        16               Philippe Katerine
#
#                       author                                        publisher  \
# 0           Kosinski, Joseph  Boulogne-Billancourt : Paramount Pictures, 2022
# 1             Miller, George            Paris : Metropolitan filmexport, 2023
# ...
